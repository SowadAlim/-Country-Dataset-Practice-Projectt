# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

df=pd.read_csv("survey_results_public.csv")

df
# Out:
#       Respondent                                         MainBranch Hobbyist  \
# 0              1                     I am a developer by profession      Yes
# 1              2                     I am a developer by profession       No
# 2              3                        I code primarily as a hobby      Yes
# 3              4                     I am a developer by profession      Yes
# 4              5  I used to be a developer by profession, but no...      Yes
# ...          ...                                                ...      ...
# 4936        4954                     I am a developer by profession      Yes
# 4937        4955             I am a student who is learning to code      Yes
# 4938        4956             I am a student who is learning to code      Yes
# 4939        4957  I am not primarily a developer, but I write co...      Yes
# 4940        4958                     I am a developer by profession      Yes
#
# ...

# %%
df1= df[["Country"]]
df1
# Out:
#                  Country
# 0                Germany
# 1         United Kingdom
# 2     Russian Federation
# 3                Albania
# 4          United States
# ...                  ...
# 4936       United States
# 4937       United States
# 4938            Colombia
# 4939       United States
# 4940       United States
#
# [4941 rows x 1 columns]

# %%
df2 =(df1.isnull().sum())
df2
# Out:
# Country    0
# dtype: int64

# %%
df3= df2.groupby('Country'). count()
(df3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-b00b294f9d06> in <module>
# ----> 1 df3= df2.groupby('Country'). count()
#       2 (df3)
#
# ~\.conda\lib\site-packages\pandas\core\series.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    1718         axis = self._get_axis_number(axis)
#    1719
# -> 1720         return SeriesGroupBy(
#    1721             obj=self,
#    1722             keys=by,
#
# ~\.conda\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     558             from pandas.core.groupby.grouper import get_grouper
#     559
# --> 560             grouper, exclusions, obj = get_grouper(
#     561                 obj,
#     562                 keys,
#
# ...

# %%
df4 = df3['Country'].value_counts()
df4
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-9e462bcff0c3> in <module>
# ----> 1 df4 = df3['Country'].value_counts()
#       2 df4
#
# AttributeError: 'numpy.int64' object has no attribute 'value_counts'

# %%
df2['Country'].value_counts().plot(kind="bar", figsize=(15,7))

 
plt.xlabel("Variety of Countries")
plt.ylabel("Percentage")
plt.title("Country")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-efe7869807d1> in <module>
# ----> 1 df2['Country'].value_counts().plot(kind="bar", figsize=(15,7))
#       2
#       3
#       4 plt.xlabel("Variety of Countries")
#       5 plt.ylabel("Percentage")
#
# AttributeError: 'numpy.int64' object has no attribute 'value_counts'
